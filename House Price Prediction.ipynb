# %%
your_local_path="E:/python/kaggle/linear regression/"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv(your_local_path+'kc_house_data.csv')
data
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# Data Visuvalizing

# %%
data.plot(kind='scatter',x='bedrooms',y='price',figsize=(10,7))

# %%
plt.figure(figsize=(10,7))
plt.scatter(data.bathrooms,data.price)
plt.xlabel('bathrooms')
plt.ylabel('price')
# Out:
# Text(0,0.5,'price')

# %%
sns.lmplot('bedrooms','price', data=data,aspect=2.5,scatter_kws={'alpha':0.5})

# %%
data.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
sns.heatmap(data.corr())

# %%
sns.distplot(data.price,color='red')

# %%
sns.boxplot(x='sqft_living',y='price' ,data=data,fliersize=5,color='blue',saturation=0.75,width=0.8,dodge=True)

# %% [markdown]
# Linear Regression Model

# %%
feature_cols=data[['sqft_basement','floors','bedrooms','bathrooms','sqft_living','sqft_lot','sqft_living15',
                   'sqft_lot15','sqft_basement']]

y = data['price']

# %%
sns.pairplot(data,x_vars=feature_cols,y_vars=y,kind='reg')

# %%
feature_cols.shape
y.shape
# Out:
# (21613,)

# %%
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(feature_cols,y,test_size=0.25,random_state=1)

# %%
print(X_train.shape,X_test.shape)
# Out:
# (16209, 9) (5404, 9)

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predict=model.predict(X_test)

# %%
predict[1]
# Out:
# 411529.1859460793

# %%
data.price[1]
# Out:
# 538000.0

# %%
print(model.intercept_)
print(model.coef_)
# Out:
# 13145.18594607932
# [-3.07919823e+13  2.13047461e+04 -5.43389756e+04 -1.78286554e+03
#   2.56882812e+02  6.05468750e-02  7.09472656e+01 -8.51562500e-01
#   3.07919823e+13]

# %%
print('MSE:',metrics.mean_squared_error(y_test,predict))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,predict)))
# Out:
# MSE: 75551948478.698
# RMSE: 274867.1469613966

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
feature_cols1=data[['sqft_basement','floors','bedrooms','bathrooms','sqft_living','sqft_lot','sqft_living15',
                   'sqft_lot15','sqft_basement','waterfront','view','condition','grade','sqft_above','sqft_basement',
                   'yr_built','yr_renovated','zipcode','lat','long',]]
y1=data['price']

# %%
X_train,X_test,y_train,y_test = train_test_split(feature_cols1,y1,test_size=0.25,random_state=1)

# %%
X_train.shape
# Out:
# (16209, 20)

# %%
model1=LinearRegression()

# %%
model1.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predict1=model1.predict(X_test)

# %%
predict1[1]
# Out:
# 478013.9923528675

# %%
data.price[1]
# Out:
# 538000.0

# %%
model1.coef_
# Out:
# array([-1.05650065e+14,  1.03892500e+04, -3.29012734e+04,  3.61007734e+04,
#         3.08177785e+13,  9.47265625e-02,  1.86773682e+01, -3.59497070e-01,
#         3.74159509e+13,  5.69585842e+05,  5.05156309e+04,  2.77341787e+04,
#         9.55737507e+04, -3.08177785e+13,  3.74163355e+13, -2.52924902e+03,
#         2.16160889e+01, -5.59145020e+02,  6.14357538e+05, -2.06117633e+05])

# %%
print(model1.coef_)
print(model1.intercept_)
# Out:
# [-1.05650065e+14  1.03892500e+04 -3.29012734e+04  3.61007734e+04
#   3.08177785e+13  9.47265625e-02  1.86773682e+01 -3.59497070e-01
#   3.74159509e+13  5.69585842e+05  5.05156309e+04  2.77341787e+04
#   9.55737507e+04 -3.08177785e+13  3.74163355e+13 -2.52924902e+03
#   2.16160889e+01 -5.59145020e+02  6.14357538e+05 -2.06117633e+05]
# 4733913.185946079

# %%
df_coef=pd.DataFrame(model1.coef_,feature_cols1.columns)
df_coef
# Out:
#                           0
# sqft_basement -1.056501e+14
# floors         1.038925e+04
# bedrooms      -3.290127e+04
# bathrooms      3.610077e+04
# sqft_living    3.081778e+13
# sqft_lot       9.472656e-02
# sqft_living15  1.867737e+01
# sqft_lot15    -3.594971e-01
# sqft_basement  3.741595e+13
# waterfront     5.695858e+05
# view           5.051563e+04
# condition      2.773418e+04
# grade          9.557375e+04
# sqft_above    -3.081778e+13
# sqft_basement  3.741634e+13
# yr_built      -2.529249e+03
# yr_renovated   2.161609e+01
# zipcode       -5.591450e+02
# lat            6.143575e+05
# long          -2.061176e+05

# %% [markdown]
# RMSE

# %%
from sklearn import metrics

# %%
print('MAE:',metrics.mean_absolute_error(y_test,predict1))
print('MSE:',metrics.mean_squared_error(y_test,predict1))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,predict1)))
# Out:
# MAE: 129024.1849669695
# MSE: 50219401486.25807
# RMSE: 224096.85737702364
